# %% [markdown]
# # Переменные окружения и обработка файлов

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DIRECTORY = 'drive/MyDrive/Informatics/Sphere@mail.ru/IR/hw_04/'
DATA_DIRECTORY = !cat $DIRECTORY/data_path.txt
DATA_DIRECTORY = DATA_DIRECTORY[0]
DATA_SPLIT_DIRECTORY = DATA_DIRECTORY + 'docs/'

# %%
# %%time
# !cp $DIRECTORY/*.tsv .
# !cp $DIRECTORY/*.csv .
# !cp $DIRECTORY/*.pkl .

# %%
import os
DATA_FILES = os.listdir(DATA_SPLIT_DIRECTORY)

# %% [markdown]
# # Функции

# %%
import time
def make_submission(submission):
    name = time.asctime() + '_submission.csv'
    submission.to_csv(name, index=False)
    return name

# %%
import pickle
import os

def save_model(model, filename, copy_to_drive=False):
    if not filename.endswith('.pkl'):
        filename = filename + '.pkl'
    with open(filename, 'wb') as f:
        pickle.dump(model, f) 
    byte_size = os.stat(filename).st_size
    for name in ['B', 'KB', 'MB', 'GB']:
        if byte_size > 1024:
            byte_size /= 1024
        else:
            break
    print(filename, 'saved!')
    print(byte_size, name)
    if copy_to_drive:
        # !cp $filename $DIRECTORY/$filename
        print('Copy done!')


def load_model(filename):
    if not filename.endswith('.pkl'):
        filename = filename + '.pkl'
    with open(filename, 'rb') as f:
        model = pickle.load(f) 
    return model

# %%
from gensim.matutils import softcossim

# %%
def make_rank_from_embeddings(get_emb_func, get_emb_func_corpus, model_name='', save_every=100, copy_to_drive_after=True, use_bm25=False):
    rank_list = []
    last_save_query_id = -save_every - 1
    current_type = 'all'  # 'all' or 'one'
    if model_name:
        model_name += '_'

    for query_id in tqdm(range(len(queries))):
        if query_id in [207, 1204, 2265]:
            current_type = 'one'
        else:
            current_type = 'all'
        new_data = False
        
        if query_id not in query_id_to_embeddings:
            query = queries[query_id]
            query = ' '.join(query)
            query_embeddings = get_emb_func(query, query_id=query_id)
            query_id_to_embeddings[query_id] = query_embeddings
            new_data = True
        query_embeddings = query_id_to_embeddings[query_id]

        doc_ids = []
        headers = []
        scores = []
        for doc_id in query_to_docs[query_id]:
            header = docs_headers[doc_id]
            header = ' '.join(header)
            headers.append(header)
            doc_ids.append(doc_id)
            
            if current_type == 'one':
                if doc_id not in doc_id_to_embeddings:
                    header_embeddings = get_emb_func(header, doc_id=doc_id)
                    doc_id_to_embeddings[doc_id] = header_embeddings
                    new_data = True
                header_embeddings = doc_id_to_embeddings[doc_id]
                score = cosine_similarity(query_embeddings, header_embeddings)[0][0]
                scores.append(score)

        scores = np.asarray(scores)
        doc_ids = np.array(doc_ids)
        if len(headers) == 0:
            continue

        if current_type == 'all':
            if query_id not in query_id_to_header_embeddings:
                header_embeddings = get_emb_func_corpus(headers, query_id, doc_ids)
                query_id_to_header_embeddings[query_id] = header_embeddings
                new_data = True
            header_embeddings = query_id_to_header_embeddings[query_id]
            
            scores = cosine_similarity(query_embeddings, header_embeddings)
            scores = np.reshape(scores, (-1,))
        
        if use_bm25:
            bm_25_scores = []
            for doc_id in doc_ids:
                query = queries[query_id]
                header = docs_headers[doc_id]
                bm25_score = BM25_score(title=header, query=query)
                bm_25_scores.append(bm25_score)
            bm_25_scores = np.array(bm_25_scores)
            th = 0.5
            bm_25_scores = np.where(bm_25_scores > th, 1, 0.1)
            scores = scores * bm_25_scores

        sorted_indices = list(np.argsort(scores)[::-1])
        cur_doc_ids = doc_ids[sorted_indices]

        for doc_id in cur_doc_ids:
            rank_list.append((query_id, doc_id))
        
        if new_data and query_id - last_save_query_id > save_every:
            last_save_query_id = query_id
            print(f'\rCurrent query_id is {query_id}')
            save_model(query_id_to_embeddings, model_name + 'query_id_to_embeddings', copy_to_drive=False)
            save_model(doc_id_to_embeddings, model_name + 'doc_id_to_embeddings', copy_to_drive=False)
            save_model(query_id_to_header_embeddings, model_name + 'query_id_to_header_embeddings', copy_to_drive=False)
            print()
    if new_data or copy_to_drive_after:
        save_model(query_id_to_embeddings, model_name + 'query_id_to_embeddings', copy_to_drive=copy_to_drive_after)
        save_model(doc_id_to_embeddings, model_name + 'doc_id_to_embeddings', copy_to_drive=copy_to_drive_after)
        save_model(query_id_to_header_embeddings, model_name + 'query_id_to_header_embeddings', copy_to_drive=copy_to_drive_after)

    return rank_list

# %% [markdown]
# # Загрузка данных

# %%
import numpy as np
import pandas as pd

from tqdm.autonotebook import tqdm
from itertools import count
from collections import defaultdict

import pickle
import json

from collections import Counter
from sklearn.metrics.pairwise import cosine_similarity

# %%
sample_submission = pd.read_csv('sample.csv')
sample_submission
# Out:
#         QueryId  DocumentId
# 0             0      340485
# 1             0       68106
# 2             0      237314
# 3             0      203791
# 4             0       53265
# ...         ...         ...
# 403966     6310      295145
# 403967     6310      257785
# 403968     6310      151034
# 403969     6310      551291
# 403970     6310      350313
#
# [403971 rows x 2 columns]

# %%
queries = pd.read_csv('queries.tsv', sep='\t', header=None, index_col=0)
queries
# Out:
#                                                       1
# 0
# 0                                      13 причин почему
# 1            1 положительный и 1 отрицательный могут ли
# 2      2016 действует ли зао рождественская мануфактура
# 3     1 месяц после операции на кишечнику диета что ...
# 4                   2 правды 1 ложь что можно придумать
# ...                                                 ...
# 6306            является ли тойота хариер внедорожником
# 6307                           як можно очистити крейду
# 6308        являются ли реактивы медицинскими изделиями
# 6309  являются ли словообразовательными парами слова...
# 6310  является ли ооо субъектом малого предпринимате...
#
# [6311 rows x 1 columns]

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = stopwords.words('russian')
stop_words.extend(['ru', 'сколько', 'почему', 'форум', 'онлайн', 'ответ', 'страница'])
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# !pip3 install pymorphy2[fast]

from pymorphy2 import MorphAnalyzer

morph = MorphAnalyzer()
# Out:
# Requirement already satisfied: pymorphy2[fast] in /usr/local/lib/python3.7/dist-packages (0.9.1)
# Requirement already satisfied: pymorphy2-dicts-ru<3.0,>=2.4 in /usr/local/lib/python3.7/dist-packages (from pymorphy2[fast]) (2.4.417127.4579844)
# Requirement already satisfied: docopt>=0.6 in /usr/local/lib/python3.7/dist-packages (from pymorphy2[fast]) (0.6.2)
# Requirement already satisfied: dawg-python>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from pymorphy2[fast]) (0.7.2)
# Requirement already satisfied: DAWG>=0.8; extra == "fast" in /usr/local/lib/python3.7/dist-packages (from pymorphy2[fast]) (0.8.0)

# %%
import re

re_compiled = re.compile(r'[A-Za-zА-Яа-я0-9ßғқβ]+')

# %%
my_translate_letter = {
    'ё':'е',
    'і': 'и',
    'є': 'е',
    'ї': 'й',
    'ј': 'й',
    '_': ' ',
    'ѓ': 'г',
    'ґ': 'г',
    'i': 'и',
    'ґ': 'г',
    'ў': 'у',
}

# %%
my_translate_word = {
    'rfr gj eltnm': 'как похудеть',
    'd herf': 'в руках',
    'ghbвfn': 'приват',
    'cвeтcкoгo': 'светского',
    'rjвhjв': 'ковров',
    'дол ty': 'должен',
    'чтобы пе ре ве сти зна че ние тем пе ра ту ры по шкале цель сия t c в шкалу фа рен гей та t f поль зу ют ся фор му лой f 1 8c 32 где c гра ду сы цель сия f гра ду сы фа рен гей та какая тем пе ра ту ра по шкале цель сия со от вет ству ет 6 по шкале фа рен гей та ответ округ ли те до де ся тых': 'чтобы перевести значение температуры по шкале цельсия t c в шкалу фаренгейта t f пользуются формулой f 1 8 c 32 где c градусы цельсия f градусы фаренгейта какая температура по шкале цельсия соответствует 6 по шкале фаренгейта ответ округлите до десятых',
    'mjhlt': 'word',
    'jrjвjq gjlвjlrjq': 'боковой подводкой',
    'вjkujuhflt': 'волгоград',
    'ну на ли лиwtypbz hjcnt наlpjhf': 'нужна ли лицензия ростехнадзора',
    'какие о оb gоlо hfnm для tkоuо ку оyyоuо':'какие обои подобрать для белого кухонного',
    'какbt': 'какие',
    'l i b e r t à': 'liberta',
}

# %%
# def clear_text_tokens(text):
#     global wrong_set
#     if not isinstance(text, str):
#         text = ' '.join(text)
#     for elem in my_translate_word:
#         text = re.sub(elem, my_translate_word[elem], text)
#     for symb in my_translate_letter:
#         text = re.sub(symb, my_translate_letter[symb], text)
#     text_tokens = re_compiled.findall(text)
#     tokens = []
#     for word in text_tokens:
#         word = morph.normal_forms(word)[0]
#         if word not in stop_words:
#             tokens.append(word)
#     return tokens

# %%
# !pip3 install pyaspeller

# from pyaspeller import YandexSpeller

# speller = YandexSpeller()
# Out:
# Requirement already satisfied: pyaspeller in /usr/local/lib/python3.7/dist-packages (0.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from pyaspeller) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->pyaspeller) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->pyaspeller) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->pyaspeller) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->pyaspeller) (1.24.3)

# %%
# queries_tmp = []

# for query in tqdm(queries.values):
#     query = list(query)[0].lower()
#     query = speller.spelled(query)
#     queries_tmp.append(query.split())

# queries = queries_tmp

# %%
# save_model(queries, 'queries_after_pyaspeller', copy_to_drive=True)
queries = load_model('queries_after_pyaspeller')

# %%
# for i in tqdm(range(len(queries))):
#     queries[i] = clear_text_tokens(queries[i])

# %%
# save_model(queries, 'queries_after_pyaspeller_supercleared', copy_to_drive=True)
# queries = load_model('queries_after_pyaspeller_supercleared')

# %%
for i in tqdm(range(len(queries))):
    queries[i] = preprocess(' '.join(queries[i]))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=6311.0), HTML(value='')))

# %%
# needed_ids = set(sample_submission['DocumentId'].values)
# query_to_docs = {
#     query_id: sample_submission[sample_submission['QueryId'] == query_id]['DocumentId'].values
#     for query_id in range(len(queries))
# }

# %%
# save_model(query_to_docs, 'query_to_docs', copy_to_drive=True)
query_to_docs = load_model('query_to_docs')

# %%
# docs_headers = {}

# for filename in tqdm(DATA_FILES):
#     with open(DATA_SPLIT_DIRECTORY + filename) as f:
#         for i in count():
#             line = f.readline()
#             if not line:
#                 break
#             line = line.split('\t')
#             doc_id, header = line[0], line[1].lower().split()
#             doc_id = int(doc_id)
#             if doc_id not in needed_ids:
#                 continue
#             docs_headers[doc_id] = header
#             print(f'\r{filename}:\t{i} lines processed', end='')

# # About 20 min

# %%
# save_model(docs_headers, 'needed_docs_headers', copy_to_drive=True)
docs_headers = load_model('needed_docs_headers')

# %%
# for i in tqdm(docs_headers):
#     docs_headers[i] = clear_text_tokens(docs_headers[i])
# Out:
# HBox(children=(FloatProgress(value=0.0, max=373966.0), HTML(value='')))

# %%
# save_model(docs_headers, 'needed_docs_headers_supercleared', copy_to_drive=True)
# docs_headers = load_model('needed_docs_headers_supercleared')
# Out:
# needed_docs_headers_supercleared.pkl saved!
# 56.90823459625244 MB
# Copy done!

# %%
for i in tqdm(docs_headers):
    docs_headers[i] = preprocess(' '.join(docs_headers[i]))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=373966.0), HTML(value='')))

# %% [markdown]
# # BM 25

# %%
words_all = []
words_counter = Counter()

for query in tqdm(queries):
    words_all.extend(query)
    words_counter.update(query)

for doc_id in tqdm(docs_headers):
    words_all.extend(docs_headers[doc_id])
    words_counter.update(docs_headers[doc_id])

words_all = list(set(words_all))

words_counter.most_common(10)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=6311.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=373966.0), HTML(value='')))
# [('один', 72376),
#  ('ноль', 68646),
#  ('два', 61941),
#  ('ru', 40937),
#  ('три', 25313),
#  ('форум', 23831),
#  ('пять', 22693),
#  ('четыре', 21837),
#  ('онлайн', 21018),
#  ('шесть', 19708)]

# %%
words_count = defaultdict(float)

for doc_id in tqdm(docs_headers):
    for word in set(docs_headers[doc_id]):
        words_count[word] += 1

words_idf = {word: 1.0 for word in words_all}
words_idf.update({word: 1 / word_count for word, word_count in words_count.items()})
# Out:
# HBox(children=(FloatProgress(value=0.0, max=373966.0), HTML(value='')))

# %%
avg_title_len = np.mean([len(docs_headers[doc_id]) for doc_id in docs_headers])
avg_title_len
# Out:
# 7.418759994224074

# %%
def BM25_score(title, query, k=2, b=0.75):
    bm25_score = 0.0

    query_tf = defaultdict(float)
    for word in query:
        query_tf[word] = title.count(word)
    
    for word in query:
        bm25_score += words_idf[word] * ((query_tf[word] * (k + 1)) / (query_tf[word] + k * (1 - b + b * (len(title) / avg_title_len))))
    
    return bm25_score

# %% [markdown]
# # Google

# %%
# !pip3 install tensorflow_text

import tensorflow as tf
import tensorflow_text
import tensorflow_hub as hub

module = hub.load('https://tfhub.dev/google/universal-sentence-encoder-multilingual-qa/3')
# Out:
# Requirement already satisfied: tensorflow_text in /usr/local/lib/python3.7/dist-packages (2.5.0)
# Requirement already satisfied: tensorflow-hub>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow_text) (0.12.0)
# Requirement already satisfied: tensorflow<2.6,>=2.5.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow_text) (2.5.0)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-hub>=0.8.0->tensorflow_text) (1.19.5)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-hub>=0.8.0->tensorflow_text) (3.12.4)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.6,>=2.5.0->tensorflow_text) (2.5.0)
# Requirement already satisfied: grpcio~=1.34.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.6,>=2.5.0->tensorflow_text) (1.34.1)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.6,>=2.5.0->tensorflow_text) (3.3.0)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.6,>=2.5.0->tensorflow_text) (1.12.1)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.6,>=2.5.0->tensorflow_text) (0.2.0)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.6,>=2.5.0->tensorflow_text) (0.36.2)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.6,>=2.5.0->tensorflow_text) (1.15.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.6,>=2.5.0->tensorflow_text) (1.12)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.6,>=2.5.0->tensorflow_text) (1.6.3)
# Requirement already satisfied: h5py~=3.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.6,>=2.5.0->tensorflow_text) (3.1.0)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.6,>=2.5.0->tensorflow_text) (1.1.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.6,>=2.5.0->tensorflow_text) (3.7.4.3)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.6,>=2.5.0->tensorflow_text) (0.4.0)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.6,>=2.5.0->tensorflow_text) (0.12.0)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.6,>=2.5.0->tensorflow_text) (2.5.0.dev2021032900)
# Requirement already satisfied: tensorboard~=2.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.6,>=2.5.0->tensorflow_text) (2.5.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow<2.6,>=2.5.0->tensorflow_text) (1.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.8.0->tensorflow-hub>=0.8.0->tensorflow_text) (56.1.0)
# Requirement already satisfied: cached-property; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from h5py~=3.1.0->tensorflow<2.6,>=2.5.0->tensorflow_text) (1.5.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow_text) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow_text) (2.23.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow_text) (0.4.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow_text) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow_text) (1.8.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow_text) (3.3.4)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow_text) (1.30.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow_text) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow_text) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow_text) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow_text) (2.10)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow_text) (1.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow_text) (4.0.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow_text) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow_text) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow_text) (0.2.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow_text) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow_text) (3.4.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow<2.6,>=2.5.0->tensorflow_text) (0.4.8)

# %%
model_name = 'google_supercleared'

# %%
def get_emb_func_corpus(texts, query_id, doc_ids):
    return module.signatures['response_encoder'](
                    input=tf.constant(texts),
                    context=tf.constant(texts)
                )['outputs'].numpy()

# %%
def get_emb_func(text, doc_id=None, query_id=None):
    if query_id is not None:
        return module.signatures['question_encoder'](tf.constant([text]))['outputs'].numpy()
    else:
        return module.signatures['response_encoder'](
                        input=tf.constant([text]),
                        context=tf.constant([text])
                    )['outputs'].numpy()

# %%
query_id_to_embeddings = {}
query_id_to_header_embeddings = {}
doc_id_to_embeddings = {}

# %%
query_id_to_embeddings = load_model(model_name + '_' + 'query_id_to_embeddings')
query_id_to_header_embeddings = load_model(model_name + '_' + 'query_id_to_header_embeddings')
doc_id_to_embeddings = load_model(model_name + '_' + 'doc_id_to_embeddings')

# %%
rank_list = make_rank_from_embeddings(get_emb_func, get_emb_func_corpus, model_name=model_name, copy_to_drive_after=True)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=6311.0), HTML(value='')))
# Current query_id is 205
# google_supercleared_query_id_to_embeddings.pkl saved!
# 423.9228515625 KB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 6 B
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 23.499869346618652 MB
#
# Current query_id is 307
# google_supercleared_query_id_to_embeddings.pkl saved!
# 634.4482421875 KB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 164.5029296875 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 33.84346008300781 MB
#
# Current query_id is 408
# google_supercleared_query_id_to_embeddings.pkl saved!
# 842.9580078125 KB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 164.5029296875 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 43.35876655578613 MB
#
# Current query_id is 510
# google_supercleared_query_id_to_embeddings.pkl saved!
# 1.0288400650024414 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 164.5029296875 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 55.14228057861328 MB
#
# Current query_id is 611
# google_supercleared_query_id_to_embeddings.pkl saved!
# 1.2324628829956055 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 164.5029296875 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 66.79499816894531 MB
#
# Current query_id is 713
# google_supercleared_query_id_to_embeddings.pkl saved!
# 1.4381017684936523 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 164.5029296875 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 77.91640281677246 MB
#
# Current query_id is 815
# google_supercleared_query_id_to_embeddings.pkl saved!
# 1.6437406539916992 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 164.5029296875 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 88.98690032958984 MB
#
# Current query_id is 917
# google_supercleared_query_id_to_embeddings.pkl saved!
# 1.849379539489746 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 164.5029296875 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 100.76430320739746 MB
#
# Current query_id is 1020
# google_supercleared_query_id_to_embeddings.pkl saved!
# 2.0570363998413086 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 164.5029296875 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 114.8528823852539 MB
#
# Current query_id is 1122
# google_supercleared_query_id_to_embeddings.pkl saved!
# 2.2626752853393555 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 164.5029296875 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 127.63242721557617 MB
#
# Current query_id is 1223
# google_supercleared_query_id_to_embeddings.pkl saved!
# 2.4662981033325195 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 369.2119140625 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 139.89244079589844 MB
#
# Current query_id is 1324
# google_supercleared_query_id_to_embeddings.pkl saved!
# 2.6699209213256836 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 369.2119140625 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 153.42614364624023 MB
#
# Current query_id is 1425
# google_supercleared_query_id_to_embeddings.pkl saved!
# 2.8735437393188477 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 369.2119140625 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 166.74304962158203 MB
#
# Current query_id is 1526
# google_supercleared_query_id_to_embeddings.pkl saved!
# 3.0771665573120117 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 369.2119140625 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 181.7616958618164 MB
#
# Current query_id is 1629
# google_supercleared_query_id_to_embeddings.pkl saved!
# 3.2848215103149414 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 369.2119140625 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 194.1915054321289 MB
#
# Current query_id is 1730
# google_supercleared_query_id_to_embeddings.pkl saved!
# 3.4884443283081055 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 369.2119140625 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 208.20983505249023 MB
#
# Current query_id is 1833
# google_supercleared_query_id_to_embeddings.pkl saved!
# 3.696099281311035 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 369.2119140625 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 221.5561008453369 MB
#
# Current query_id is 1935
# google_supercleared_query_id_to_embeddings.pkl saved!
# 3.901738166809082 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 369.2119140625 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 235.33028984069824 MB
#
# Current query_id is 2038
# google_supercleared_query_id_to_embeddings.pkl saved!
# 4.1093950271606445 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 369.2119140625 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 248.4438819885254 MB
#
# Current query_id is 2139
# google_supercleared_query_id_to_embeddings.pkl saved!
# 4.313017845153809 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 369.2119140625 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 262.36436653137207 MB
#
# Current query_id is 2240
# google_supercleared_query_id_to_embeddings.pkl saved!
# 4.516640663146973 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 369.2119140625 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 275.57385063171387 MB
#
# Current query_id is 2341
# google_supercleared_query_id_to_embeddings.pkl saved!
# 4.720263481140137 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 286.9624557495117 MB
#
# Current query_id is 2442
# google_supercleared_query_id_to_embeddings.pkl saved!
# 4.923886299133301 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 299.3004684448242 MB
#
# Current query_id is 2543
# google_supercleared_query_id_to_embeddings.pkl saved!
# 5.127509117126465 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 311.07780838012695 MB
#
# Current query_id is 2644
# google_supercleared_query_id_to_embeddings.pkl saved!
# 5.331131935119629 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 325.0471839904785 MB
#
# Current query_id is 2745
# google_supercleared_query_id_to_embeddings.pkl saved!
# 5.534754753112793 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 338.0515899658203 MB
#
# Current query_id is 2846
# google_supercleared_query_id_to_embeddings.pkl saved!
# 5.738377571105957 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 351.2082767486572 MB
#
# Current query_id is 2947
# google_supercleared_query_id_to_embeddings.pkl saved!
# 5.942000389099121 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 363.7397747039795 MB
#
# Current query_id is 3048
# google_supercleared_query_id_to_embeddings.pkl saved!
# 6.145625114440918 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 376.89640045166016 MB
#
# Current query_id is 3149
# google_supercleared_query_id_to_embeddings.pkl saved!
# 6.349247932434082 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 392.2686233520508 MB
#
# Current query_id is 3253
# google_supercleared_query_id_to_embeddings.pkl saved!
# 6.5589189529418945 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 406.2202949523926 MB
#
# Current query_id is 3354
# google_supercleared_query_id_to_embeddings.pkl saved!
# 6.762541770935059 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 419.5901870727539 MB
#
# Current query_id is 3455
# google_supercleared_query_id_to_embeddings.pkl saved!
# 6.966164588928223 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 432.0063877105713 MB
#
# Current query_id is 3557
# google_supercleared_query_id_to_embeddings.pkl saved!
# 7.1718034744262695 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 444.8329963684082 MB
#
# Current query_id is 3658
# google_supercleared_query_id_to_embeddings.pkl saved!
# 7.375426292419434 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 457.1163215637207 MB
#
# Current query_id is 3759
# google_supercleared_query_id_to_embeddings.pkl saved!
# 7.579049110412598 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 469.00719451904297 MB
#
# Current query_id is 3862
# google_supercleared_query_id_to_embeddings.pkl saved!
# 7.786704063415527 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 481.71447372436523 MB
#
# Current query_id is 3963
# google_supercleared_query_id_to_embeddings.pkl saved!
# 7.990326881408691 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 494.5252685546875 MB
#
# Current query_id is 4064
# google_supercleared_query_id_to_embeddings.pkl saved!
# 8.193951606750488 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 508.7484884262085 MB
#
# Current query_id is 4167
# google_supercleared_query_id_to_embeddings.pkl saved!
# 8.401606559753418 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 520.9400796890259 MB
#
# Current query_id is 4268
# google_supercleared_query_id_to_embeddings.pkl saved!
# 8.605229377746582 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 531.8517446517944 MB
#
# Current query_id is 4369
# google_supercleared_query_id_to_embeddings.pkl saved!
# 8.808852195739746 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 543.3579149246216 MB
#
# Current query_id is 4470
# google_supercleared_query_id_to_embeddings.pkl saved!
# 9.01247501373291 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 556.1590070724487 MB
#
# Current query_id is 4571
# google_supercleared_query_id_to_embeddings.pkl saved!
# 9.216097831726074 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 571.743745803833 MB
#
# Current query_id is 4672
# google_supercleared_query_id_to_embeddings.pkl saved!
# 9.419720649719238 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 584.4432125091553 MB
#
# Current query_id is 4774
# google_supercleared_query_id_to_embeddings.pkl saved!
# 9.625359535217285 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 599.1998233795166 MB
#
# Current query_id is 4876
# google_supercleared_query_id_to_embeddings.pkl saved!
# 9.830998420715332 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 611.545711517334 MB
#
# Current query_id is 4977
# google_supercleared_query_id_to_embeddings.pkl saved!
# 10.034621238708496 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 623.4189434051514 MB
#
# Current query_id is 5078
# google_supercleared_query_id_to_embeddings.pkl saved!
# 10.238245964050293 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 636.6128025054932 MB
#
# Current query_id is 5181
# google_supercleared_query_id_to_embeddings.pkl saved!
# 10.445900917053223 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 649.1247692108154 MB
#
# Current query_id is 5283
# google_supercleared_query_id_to_embeddings.pkl saved!
# 10.65153980255127 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 661.9806118011475 MB
#
# Current query_id is 5386
# google_supercleared_query_id_to_embeddings.pkl saved!
# 10.8591947555542 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 673.4865303039551 MB
#
# Current query_id is 5487
# google_supercleared_query_id_to_embeddings.pkl saved!
# 11.062817573547363 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 685.3849010467529 MB
#
# Current query_id is 5588
# google_supercleared_query_id_to_embeddings.pkl saved!
# 11.266440391540527 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 699.4364337921143 MB
#
# Current query_id is 5689
# google_supercleared_query_id_to_embeddings.pkl saved!
# 11.470063209533691 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 711.7372741699219 MB
#
# Current query_id is 5790
# google_supercleared_query_id_to_embeddings.pkl saved!
# 11.673686027526855 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 724.8099136352539 MB
#
# Current query_id is 5893
# google_supercleared_query_id_to_embeddings.pkl saved!
# 11.881340980529785 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 738.0154285430908 MB
#
# Current query_id is 5994
# google_supercleared_query_id_to_embeddings.pkl saved!
# 12.08496379852295 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 750.1677684783936 MB
#
# Current query_id is 6095
# google_supercleared_query_id_to_embeddings.pkl saved!
# 12.288588523864746 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 763.174129486084 MB
#
# Current query_id is 6196
# google_supercleared_query_id_to_embeddings.pkl saved!
# 12.49221134185791 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 774.8637676239014 MB
#
# Current query_id is 6298
# google_supercleared_query_id_to_embeddings.pkl saved!
# 12.697850227355957 MB
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 786.5553588867188 MB
#
#
# google_supercleared_query_id_to_embeddings.pkl saved!
# 12.72204303741455 MB
# Copy done!
# google_supercleared_doc_id_to_embeddings.pkl saved!
# 590.6318359375 KB
# Copy done!
# google_supercleared_query_id_to_header_embeddings.pkl saved!
# 788.7162075042725 MB
# Copy done!

# %% [markdown]
# # Google + BM25

# %%
model_name = 'google'

# %%
query_id_to_embeddings = load_model(model_name + '_' + 'query_id_to_embeddings')
query_id_to_header_embeddings = load_model(model_name + '_' + 'query_id_to_header_embeddings')
doc_id_to_embeddings = load_model(model_name + '_' + 'doc_id_to_embeddings')

# %%
rank_list = make_rank_from_embeddings(get_emb_func, get_emb_func_corpus, model_name=model_name, copy_to_drive_after=False, use_bm25=True)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=6311.0), HTML(value='')))

# %% [markdown]
# # Fasttext

# %%
# !pip3 install fasttext

import fasttext
# Out:
# Collecting fasttext
#   Downloading https://files.pythonhosted.org/packages/f8/85/e2b368ab6d3528827b147fdb814f8189acc981a4bc2f99ab894650e05c40/fasttext-0.9.2.tar.gz (68kB)
#      |████████████████████████████████| 71kB 3.5MB/s
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.7/dist-packages (from fasttext) (2.6.2)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from fasttext) (56.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from fasttext) (1.19.5)
# Building wheels for collected packages: fasttext
#   Building wheel for fasttext (setup.py) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp37-cp37m-linux_x86_64.whl size=3098485 sha256=fbe8aa42a70080d1ade3a017f1e2b732fee492896e36d7b61c920e4053ae7576
#   Stored in directory: /root/.cache/pip/wheels/98/ba/7f/b154944a1cf5a8cee91c154b75231136cc3a3321ab0e30f592
# Successfully built fasttext
# Installing collected packages: fasttext
# Successfully installed fasttext-0.9.2

# %%
fasttext_name = 'cc.ru.300.bin'
if not os.path.exists(fasttext_name):
    # !cp $DATA_DIRECTORY/$fasttext_name ./$fasttext_name
else:
    print('No copy')

# %%
# import fasttext.util
# fasttext.util.download_model('ru', if_exists='ignore')

# %%
ft = fasttext.load_model('cc.ru.300.bin')
# Out:
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %%
model_name = 'fasttext'

# %%
query_id_to_embeddings = {}
query_id_to_header_embeddings = {}
doc_id_to_embeddings = {}

# %%
def get_emb_func(text, doc_id=None, query_id=None):
    return ft.get_sentence_vector(text).reshape((-1, 300))

# %%
def get_emb_func_corpus(texts, query_id, doc_ids):
    res = []
    for i, doc_id in enumerate(doc_ids):
        if doc_id in doc_id_to_embeddings:
            res.append(doc_id_to_embeddings[doc_id])
        else:
            res.append(get_emb_func(texts[i], doc_id=doc_id))
    res = np.array(res).reshape(-1, 300)
    return res

# %%
rank_list = make_rank_from_embeddings(get_emb_func, get_emb_func_corpus, model_name=model_name, copy_to_drive_after=False, use_bm25=True)

# %% [markdown]
# # Google + ft

# %%
query_id_to_embeddings = {}
doc_id_to_embeddings = {}
query_id_to_header_embeddings = {}

# %%
model_name = 'fasttext_google'

# %%
query_id_to_embeddings_fasttext = load_model('fasttext_query_id_to_embeddings')
doc_id_to_embeddings_fasttext = load_model('fasttext_doc_id_to_embeddings')
query_id_to_header_embeddings_fasttext = load_model('fasttext_query_id_to_header_embeddings')

# %%
query_id_to_embeddings_google = load_model('google_query_id_to_embeddings')
query_id_to_header_embeddings_google = load_model('google_query_id_to_header_embeddings')
doc_id_to_embeddings_google = load_model('google_doc_id_to_embeddings')

# %%
def get_emb_func_corpus(texts, query_id, doc_ids):
    return np.hstack((
        query_id_to_header_embeddings_google[query_id],
        query_id_to_header_embeddings_fasttext[query_id]
    ))

# %%
def get_emb_func(text, doc_id=None, query_id=None):
    if query_id is not None:
        if query_id not in query_id_to_embeddings_google:
            return np.array([])
        return np.hstack((
            query_id_to_embeddings_google[query_id],
            query_id_to_embeddings_fasttext[query_id]
        ))
    else:
        return np.hstack((
            doc_id_to_embeddings_google[doc_id],
            doc_id_to_embeddings_fasttext[doc_id]
        ))

# %%
query_id_to_embeddings = {}
doc_id_to_embeddings = {}
query_id_to_header_embeddings = {}

# %%
rank_list = make_rank_from_embeddings(get_emb_func, get_emb_func_corpus, model_name=model_name, copy_to_drive_after=True)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=6311.0), HTML(value='')))
# Current query_id is 0
# fasttext_google_query_id_to_embeddings.pkl saved!
# 3.3330078125 KB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 6 B
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 533.0361328125 KB
#
# Current query_id is 101
# fasttext_google_query_id_to_embeddings.pkl saved!
# 329.10546875 KB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 6 B
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 18.347030639648438 MB
#
# Current query_id is 204
# fasttext_google_query_id_to_embeddings.pkl saved!
# 662.044921875 KB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 6 B
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 37.02310562133789 MB
#
# Current query_id is 307
# fasttext_google_query_id_to_embeddings.pkl saved!
# 995.03515625 KB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 257.0810546875 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 53.666693687438965 MB
#
# Current query_id is 408
# fasttext_google_query_id_to_embeddings.pkl saved!
# 1.290633201599121 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 257.0810546875 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 68.7551097869873 MB
#
# Current query_id is 510
# fasttext_google_query_id_to_embeddings.pkl saved!
# 1.6127099990844727 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 257.0810546875 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 87.44036388397217 MB
#
# Current query_id is 611
# fasttext_google_query_id_to_embeddings.pkl saved!
# 1.9316291809082031 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 257.0810546875 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 105.9181432723999 MB
#
# Current query_id is 713
# fasttext_google_query_id_to_embeddings.pkl saved!
# 2.2537059783935547 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 257.0810546875 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 123.5533332824707 MB
#
# Current query_id is 815
# fasttext_google_query_id_to_embeddings.pkl saved!
# 2.5757827758789062 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 257.0810546875 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 141.10786724090576 MB
#
# Current query_id is 917
# fasttext_google_query_id_to_embeddings.pkl saved!
# 2.897859573364258 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 257.0810546875 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 159.78358840942383 MB
#
# Current query_id is 1020
# fasttext_google_query_id_to_embeddings.pkl saved!
# 3.2230958938598633 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 257.0810546875 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 182.12429332733154 MB
#
# Current query_id is 1122
# fasttext_google_query_id_to_embeddings.pkl saved!
# 3.545172691345215 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 257.0810546875 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 202.3892297744751 MB
#
# Current query_id is 1223
# fasttext_google_query_id_to_embeddings.pkl saved!
# 3.8640918731689453 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 576.6337890625 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 221.83022212982178 MB
#
# Current query_id is 1324
# fasttext_google_query_id_to_embeddings.pkl saved!
# 4.183011054992676 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 576.6337890625 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 243.29104709625244 MB
#
# Current query_id is 1425
# fasttext_google_query_id_to_embeddings.pkl saved!
# 4.501930236816406 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 576.6337890625 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 264.4080457687378 MB
#
# Current query_id is 1526
# fasttext_google_query_id_to_embeddings.pkl saved!
# 4.820849418640137 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 576.6337890625 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 288.223539352417 MB
#
# Current query_id is 1629
# fasttext_google_query_id_to_embeddings.pkl saved!
# 5.146083831787109 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 576.6337890625 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 307.9338970184326 MB
#
# Current query_id is 1730
# fasttext_google_query_id_to_embeddings.pkl saved!
# 5.46500301361084 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 576.6337890625 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 330.1631507873535 MB
#
# Current query_id is 1833
# fasttext_google_query_id_to_embeddings.pkl saved!
# 5.7902374267578125 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 576.6337890625 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 351.3266725540161 MB
#
# Current query_id is 1935
# fasttext_google_query_id_to_embeddings.pkl saved!
# 6.112314224243164 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 576.6337890625 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 373.1687345504761 MB
#
# Current query_id is 2038
# fasttext_google_query_id_to_embeddings.pkl saved!
# 6.4375505447387695 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 576.6337890625 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 393.9634094238281 MB
#
# Current query_id is 2139
# fasttext_google_query_id_to_embeddings.pkl saved!
# 6.7564697265625 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 576.6337890625 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 416.03760623931885 MB
#
# Current query_id is 2240
# fasttext_google_query_id_to_embeddings.pkl saved!
# 7.0753889083862305 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 576.6337890625 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 436.9842405319214 MB
#
# Current query_id is 2341
# fasttext_google_query_id_to_embeddings.pkl saved!
# 7.394308090209961 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 455.0434322357178 MB
#
# Current query_id is 2442
# fasttext_google_query_id_to_embeddings.pkl saved!
# 7.713227272033691 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 474.6082057952881 MB
#
# Current query_id is 2543
# fasttext_google_query_id_to_embeddings.pkl saved!
# 8.032146453857422 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 493.2838668823242 MB
#
# Current query_id is 2644
# fasttext_google_query_id_to_embeddings.pkl saved!
# 8.351065635681152 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 515.4355621337891 MB
#
# Current query_id is 2745
# fasttext_google_query_id_to_embeddings.pkl saved!
# 8.669984817504883 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 536.0569553375244 MB
#
# Current query_id is 2846
# fasttext_google_query_id_to_embeddings.pkl saved!
# 8.988903999328613 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 556.9198961257935 MB
#
# Current query_id is 2947
# fasttext_google_query_id_to_embeddings.pkl saved!
# 9.307823181152344 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 576.7914457321167 MB
#
# Current query_id is 3048
# fasttext_google_query_id_to_embeddings.pkl saved!
# 9.626744270324707 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 597.6543283462524 MB
#
# Current query_id is 3149
# fasttext_google_query_id_to_embeddings.pkl saved!
# 9.945663452148438 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 622.0305337905884 MB
#
# Current query_id is 3253
# fasttext_google_query_id_to_embeddings.pkl saved!
# 10.274055480957031 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 644.1542310714722 MB
#
# Current query_id is 3354
# fasttext_google_query_id_to_embeddings.pkl saved!
# 10.592974662780762 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 665.3551034927368 MB
#
# Current query_id is 3455
# fasttext_google_query_id_to_embeddings.pkl saved!
# 10.911893844604492 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 685.0438385009766 MB
#
# Current query_id is 3557
# fasttext_google_query_id_to_embeddings.pkl saved!
# 11.233970642089844 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 705.3832960128784 MB
#
# Current query_id is 3658
# fasttext_google_query_id_to_embeddings.pkl saved!
# 11.552889823913574 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 724.8613386154175 MB
#
# Current query_id is 3759
# fasttext_google_query_id_to_embeddings.pkl saved!
# 11.871809005737305 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 743.7168970108032 MB
#
# Current query_id is 3862
# fasttext_google_query_id_to_embeddings.pkl saved!
# 12.197043418884277 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 763.8672246932983 MB
#
# Current query_id is 3963
# fasttext_google_query_id_to_embeddings.pkl saved!
# 12.515962600708008 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 784.1817216873169 MB
#
# Current query_id is 4064
# fasttext_google_query_id_to_embeddings.pkl saved!
# 12.834883689880371 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 806.7360372543335 MB
#
# Current query_id is 4167
# fasttext_google_query_id_to_embeddings.pkl saved!
# 13.160118103027344 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 826.0685558319092 MB
#
# Current query_id is 4268
# fasttext_google_query_id_to_embeddings.pkl saved!
# 13.479037284851074 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 843.3715887069702 MB
#
# Current query_id is 4369
# fasttext_google_query_id_to_embeddings.pkl saved!
# 13.797956466674805 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 861.6169929504395 MB
#
# Current query_id is 4470
# fasttext_google_query_id_to_embeddings.pkl saved!
# 14.116875648498535 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 881.9160623550415 MB
#
# Current query_id is 4571
# fasttext_google_query_id_to_embeddings.pkl saved!
# 14.435794830322266 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 906.6295413970947 MB
#
# Current query_id is 4672
# fasttext_google_query_id_to_embeddings.pkl saved!
# 14.754714012145996 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 926.7674789428711 MB
#
# Current query_id is 4774
# fasttext_google_query_id_to_embeddings.pkl saved!
# 15.076790809631348 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 950.1676006317139 MB
#
# Current query_id is 4876
# fasttext_google_query_id_to_embeddings.pkl saved!
# 15.3988676071167 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 969.7448244094849 MB
#
# Current query_id is 4977
# fasttext_google_query_id_to_embeddings.pkl saved!
# 15.71778678894043 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 988.5724449157715 MB
#
# Current query_id is 5078
# fasttext_google_query_id_to_embeddings.pkl saved!
# 16.036707878112793 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 1009.4942989349365 MB
#
# Current query_id is 5181
# fasttext_google_query_id_to_embeddings.pkl saved!
# 16.361942291259766 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 1.0052098371088505 GB
#
# Current query_id is 5283
# fasttext_google_query_id_to_embeddings.pkl saved!
# 16.684019088745117 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 1.0251179039478302 GB
#
# Current query_id is 5386
# fasttext_google_query_id_to_embeddings.pkl saved!
# 17.00925350189209 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 1.0429354468360543 GB
#
# Current query_id is 5487
# fasttext_google_query_id_to_embeddings.pkl saved!
# 17.32817268371582 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 1.0613608844578266 GB
#
# Current query_id is 5588
# fasttext_google_query_id_to_embeddings.pkl saved!
# 17.64709186553955 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 1.0831205639988184 GB
#
# Current query_id is 5689
# fasttext_google_query_id_to_embeddings.pkl saved!
# 17.96601104736328 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 1.1021692557260394 GB
#
# Current query_id is 5790
# fasttext_google_query_id_to_embeddings.pkl saved!
# 18.28493022918701 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 1.1224130904302 GB
#
# Current query_id is 5893
# fasttext_google_query_id_to_embeddings.pkl saved!
# 18.610164642333984 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 1.1428626794368029 GB
#
# Current query_id is 5994
# fasttext_google_query_id_to_embeddings.pkl saved!
# 18.929083824157715 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 1.161681417375803 GB
#
# Current query_id is 6095
# fasttext_google_query_id_to_embeddings.pkl saved!
# 19.248004913330078 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 1.1818225234746933 GB
#
# Current query_id is 6196
# fasttext_google_query_id_to_embeddings.pkl saved!
# 19.56692409515381 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 1.1999245276674628 GB
#
# Current query_id is 6298
# fasttext_google_query_id_to_embeddings.pkl saved!
# 19.88900089263916 MB
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 1.2180295567959547 GB
#
#
# fasttext_google_query_id_to_embeddings.pkl saved!
# 19.926892280578613 MB
# Copy done!
# fasttext_google_doc_id_to_embeddings.pkl saved!
# 922.2724609375 KB
# Copy done!
# fasttext_google_query_id_to_header_embeddings.pkl saved!
# 1.2213757811114192 GB
# Copy done!

# %% [markdown]
# # Submission

# %%
submission = pd.DataFrame(rank_list, columns=sample_submission.columns)
submission[submission.QueryId == 0]
# Out:
#      QueryId  DocumentId
# 0          0      563677
# 1          0      461894
# 2          0       49847
# 3          0       64459
# 4          0      113720
# ..       ...         ...
# 163        0      566487
# 164        0      107045
# 165        0      564616
# 166        0      515943
# 167        0      515944
#
# [168 rows x 2 columns]

# %%
name = make_submission(submission)

# %%
name
# Out:
# 'Mon May 31 22:23:42 2021_submission.csv'
